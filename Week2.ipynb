# %% [markdown]
# <a href="https://colab.research.google.com/github/denuradhan/PVCK_GENAP_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpg')
plt.imshow(img)

# %%
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img_high = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img_high)

# %%
img_flip = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img_flip)

# %%
black_img = np.zeros(shape=(512,521,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness= 10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness= 15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness= 8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, 'Hello', (10,500), font, 4, (255,255,0), 2, cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2= np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts], True,(255,0,0), 5)
plt.imshow(black_img2)

# %%
img_rg = img3
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img
# img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
img_arr = img[10:100,10:100]
plt.imshow(img_arr)

# %%
plt.imshow(img[5:30])

# %%
img_k = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img_k, pt1=(0,100), pt2=(100,175), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(100,0), pt2=(175,100), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(50,50), pt2=(150,150), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(75,125), pt2=(260,180), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(225,10), pt2=(275,75), color=(255,255,255), thickness=3)

plt.imshow(img_k)

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_t)

# %%
imgt = img3

cv.rectangle(imgt,pt1=(450,40),pt2=(700,290),color=(255,255,255), thickness=5)
cv.circle(imgt,center=(580,170),radius=120,color=(255,0,0), thickness=5)

plt.imshow(imgt)
